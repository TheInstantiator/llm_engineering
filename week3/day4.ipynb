# %% [markdown]
# # Models
#
# And now - this colab unveils the heart (or the brains?) of the transformers library - the models:
#
# https://colab.research.google.com/drive/1hhR9Z-yiqjUe7pJjVQw4c74z_V3VchLy?usp=sharing
#
# This should run nicely on a low-cost or free T4 box.

# %% [markdown]
# # Quantitization
# Reducing the bits of the model for all the weights, you reduce the precision of them but supposedly it doesn't effect the model that much and it saves a lot of memory
#
# # NN
# 128256K tokens in
# 16 - 32 layers or more
#  - Attention layers question, key, value, output
#  -
# 128256K tokens out with the probability of whether its the next token
