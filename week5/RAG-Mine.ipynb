# %% [markdown]
# # RAG Retreival Augmented Generation
# Chatbot -> Code -> Knowledge Base -> Combine Question and Knowledge Base -> LLM -> Answer
#
# ## Insurance Tech Startup
# - We have a knowledge base on a shared drive
# - We want to build an AI Knowledge worker that knows about the company based on the information in the knowledge base
#
# ### Blunt approach
# - Rean names of products and employees from the knowledge base
# - See if the question is about a product or employee
# - shove the relevant document information into the LLM
# - LLM answers the question
